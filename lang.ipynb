# %%
import pandas as pd

from pathlib import Path

from papers_lab.io import Storage, PaperTransform

# %%
object_oriented_languages = [
    "Python",
    "Java",
    "C++",
    "C#",
    "JavaScript",
    "TypeScript"
]
