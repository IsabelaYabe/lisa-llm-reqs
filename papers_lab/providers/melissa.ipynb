# %%
dictionary = {"book": "livro", "one": "um", "two": "dois"}

# %%
print(dictionary["book"])
# Out:
# livro

# %%
exemple = 'exemplo'
names = {"name_1":"Melissa", "name_2": "Isabela"}
format_string = f"Hello, {names['name_1']}"

# %%
for key, value in names.items():
    print(f"Key: {key}")
    print(f"Hello, {value}")
# Out:
# Key: name_1
# Hello, Melissa
# Key: name_2
# Hello, Isabela
