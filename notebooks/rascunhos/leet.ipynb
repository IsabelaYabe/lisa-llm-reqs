# %%
import pandas as pd
import os
df = pd.read_json(os.path.join("data", "pure_req_user_stories_annotateSS.json"))
print(df.columns)
# Out:
# Index(['filename', 'keys', 'requirement', 'user story llama-4-maverick',
#        'user story llama-3-3-70b', 'user story llama-3-1-405b',
#        'user story dbrx', 'user story mixtral-8x7b',
#        'user story (us llama-4-maverick)',
#        'user story parts (us llama-4-maverick)',
#        'user story (us llama-3-3-70b)', 'user story parts (us llama-3-3-70b)',
#        'user story (us llama-3-1-405b)',
#        'user story parts (us llama-3-1-405b)', 'user story (us dbrx)',
#        'user story parts (us dbrx)', 'user story (us mixtral-8x7b)',
#        'user story parts (us mixtral-8x7b)'],
#       dtype='object')

# %%
for i in range(len(df)):
    row = df["user story (us llama-3-3-70b)"].iloc[i] 
    if len(row) > 1:
        print(i)
        print(row)
        print("===")
# Out:
# 25
# ["As a system administrator, I want to be able to configure the system to handle unauthorized access to cases in one of three ways: displaying title and metadata, displaying existence without details, or not indicating existence at all, so that I can balance security and usability according to the organization's needs and the sensitivity of the cases.", "As a user, I want the system to respond appropriately when I try to access a case I don't have permission for, by either showing me some information, indicating that a case exists without showing details, or not showing anything at all, so that I can understand the access restrictions and the system can protect sensitive information."]
# ===
# 59
# ...

# %%
def soma(a,b):
    return a+b

def multiplica(a,b):
    return a*b

lista = [(2,3),(5,3),(2,3)]

def dir_interable(dir, **kwargs):
        returns_functions = {}

        for value in kwargs.keys():
            returns_functions[value] = []
        
        for file in dir:
            for value, function in kwargs.items():
                returns_functions[value].append(function(dir, file))
        
        return returns_functions


#def exemplo_retorno_dict(lista):
#     return {"lista": lista, "lista2": ["oi"]}
#
#a, b = exemplo_retorno_dict(lista)
#
#print(a)
#print(b)
# Out:
# lista
# lista2

# %%
def soma(a, b):
    return a + b

def multiplica(a, b):
    return a * b

lista = [(2, 3), (5, 3), (2, 3)]

def dir_iterable(data, **kwargs):
    returns_functions = {name: [] for name in kwargs}

    for item in data:
        for name, func in kwargs.items():
            returns_functions[name].append(func(*item))
    return returns_functions

resultados = dir_iterable(lista, soma=soma, multiplica=multiplica)

print(resultados)

# %%
def soma(a, b):
    return a + b

def multiplica(a, b):
    return a * b

lista = [(2, 3), (5, 3), (2, 3)]

dicionario = {"Bernardo": soma, "Isabela": multiplica}

def dir_iterable(data, **kwargs):
    returns_functions = {name: [] for name in kwargs}

    for item in data:
        for name, func in kwargs.items():
            returns_functions[name].append(func(*item))
    
    return returns_functions

result = dir_iterable(lista, Bernardo=soma)[0]
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 20
#      16             returns_functions[name].append(func(*item))
#      18     return returns_functions
# ---> 20 result = dir_iterable(lista, Bernardo=soma)[0]
#      21 print(result)
#
# KeyError: 0

# %%
exemplo = """D	Comms Software Requirements Specification for Defense Information Infrastructure Common Operating Environment
3	Requirements
3.2	Message Transfer Services Requirements
3.2.1	General Requirements
3.2.2	Input/Output Devices Requirements
3.2.2.2	Serial Device Requirements
3.2.2.3	Parallel Device Requirements
3.2.2.4	Network Device Requirements.
3.2.3	Input/Output Interfaces Requirements

3.2.3.2	Serial Interface
3.2.3.5	Network Interfaces"""
#exemplo = "3.2.3.5	Network Interfaces"
def _extract_metadatas(metadata_doc):
        result = {}
        lines = metadata_doc.split("\n")
        doc_name = " ".join(lines[0].split()[1:])
        lines = lines[1:]
        print(doc_name)
        for line in lines:
            if not line:
                continue
            
            line = line.split()
            key = line[0]
            print(key)
            text = " ".join(line[1:])
            print(text)
            result[key] = text

        return result

teste_2 = _extract_metadatas(exemplo)
# Out:
# Comms Software Requirements Specification for Defense Information Infrastructure Common Operating Environment
# 3
# Requirements
# 3.2
# Message Transfer Services Requirements
# 3.2.1
# General Requirements
# 3.2.2
# Input/Output Devices Requirements
# 3.2.2.2
# Serial Device Requirements
# 3.2.2.3
# Parallel Device Requirements
# 3.2.2.4
# Network Device Requirements.
# 3.2.3
# Input/Output Interfaces Requirements
# 3.2.3.2
# Serial Interface
# 3.2.3.5
# Network Interfaces

# %%
teste_1 
teste_2

if teste_1 == teste_2:
    print("Oi")
# Out:
# Oi

# %%
dicti = {"a": 1, "b": 2, "c": 3}

# função de pegar primeiro elemento do dicionário
def pegar_primeiro_elemento(dicionario):
    for chave, valor in dicionario.items():
        return chave, valor
